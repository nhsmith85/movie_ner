# %% [markdown]
# # MIT Movie Dataset - Base Estimator

# %% [markdown]
# This notebook implements a baseline predictor that exclusively uses memory to classify words (e.g., it uses the most frequent class for each word as the prediction).

# %%
import pandas as pd
import numpy as np

# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

#os.chdir('/content/drive/My Drive/Colab Notebooks/DAAN888/data')
os.chdir('/content/drive/My Drive/DAAN888/data')
os.getcwd()
# Out:
# '/content/drive/.shortcut-targets-by-id/1tuCnSXHVzIUUyCjMTEqmKbY7JxKZ-5eU/DAAN888/data'

# %%
model_dir = '/content/drive/My Drive/Colab Notebooks/DAAN888/models/'

# %%
data_dir = '/content/drive/My Drive/Colab Notebooks/DAAN888/data/'

# %% [markdown]
# ## Load Dataset

# %%
import pickle 

with open('mitmovie.pickle', 'rb') as handle:
    dataset = pickle.load(handle)

# %% [markdown]
# ## Define Base Estimator

# %% [markdown]
# Tobias Sterbak on his blog "Depends on the Definition" provides a base estimator useful for NER.
#
# https://www.depends-on-the-definition.com/introduction-named-entity-recognition-python/

# %%
from sklearn.base import BaseEstimator, TransformerMixin


class MemoryTagger(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y):
        '''
        Expects a list of words as X and a list of tags as y.
        '''
        voc = {}
        self.tags = []
        for x, t in zip(X, y):
            if t not in self.tags:
                self.tags.append(t)
            if x in voc:
                if t in voc[x]:
                    voc[x][t] += 1
                else:
                    voc[x][t] = 1
            else:
                voc[x] = {t: 1}
        self.memory = {}
        for k, d in voc.items():
            self.memory[k] = max(d, key=d.get)
    
    def predict(self, X, y=None):
        '''
        Predict the the tag from memory. If word is unknown, predict 'O'.
        '''
#        print(X)
        return [self.memory.get(x, 'O') for x in X]

# %% [markdown]
# ### Train Base Estimator

# %%
base_estimator = MemoryTagger()

# %%
# stretch out the list of lists into one list for words and labels
train_words = [words for doc in dataset['train_tokens'] for words in doc]
train_labels = [tags for doc in dataset['train_labels'] for tags in doc]

# %%
# fit estimator based on training data
base_estimator.fit(train_words, train_labels)

# %% [markdown]
# ### Evaluate Base Estimator

# %%
# stretch out the list of lists into one list for words and labels
test_words = [words for doc in dataset['test_tokens'] for words in doc]
test_labels = [tags for doc in dataset['test_labels'] for tags in doc]

# %%
# get predictions
train_preds = base_estimator.predict(train_words)
test_preds = base_estimator.predict(test_words)
# Out:
# ['what', 'movies', 'star', 'bruce', 'willis', 'show', 'me', 'films', 'with', 'drew', 'barrymore', 'from', 'the', '1980s', 'what', 'movies', 'starred', 'both', 'al', 'pacino', 'and', 'robert', 'deniro', 'find', 'me', 'all', 'of', 'the', 'movies', 'that', 'starred', 'harold', 'ramis', 'and', 'bill', 'murray', 'find', 'me', 'a', 'movie', 'with', 'a', 'quote', 'about', 'baseball', 'in', 'it', 'what', 'movies', 'have', 'mississippi', 'in', 'the', 'title', 'show', 'me', 'science', 'fiction', 'films', 'directed', 'by', 'steven', 'spielberg', 'do', 'you', 'have', 'any', 'thrillers', 'directed', 'by', 'sofia', 'coppola', 'what', 'leonard', 'cohen', 'songs', 'have', 'been', 'used', 'in', 'a', 'movie', 'show', 'me', 'films', 'elvis', 'films', 'set', 'in', 'hawaii', 'what', 'movie', 'is', 'references', 'zydrate', 'are', 'there', 'any', 'musical', 'films', 'with', 'patrick', 'dempsey', 'list', 'westerns', 'starring', 'john', 'wayne', 'show', 'me', 'military', 'related', 'movies', 'with', 'demi', 'moore', 'did', 'stephen', 'made', 'any', 'sex', 'or', 'horror', 'movie', 'that', 'must', 'be', 'have', 'to', 'watch', 'did', 'ang', 'lee', 'direct', 'a', 'costume', 'drama', 'movie', 'set', 'in', 'the', '1800s', 'who', 'directed', 'the', 'first', 'james', 'bond', 'movies', 'list', 'the', 'r', 'rated', 'best', 'picture', 'oscar', 'winners', 'where', 'can', 'i', 'buy', 'the', 'sucker', 'punch', 'soundtrack', 'what', 'british', 'movies', 'came', 'out', 'in', '1990s', 'about', 'the', 'royal', 'family', 'who', 'did', 'the', 'soundtrack', 'to', 'james', 'camerons', 'titanic', 'what', 'was', 'the', 'last', 'movie', 'judy', 'garland', 'starred', 'in', 'what', 'military', 'spoof', 'movie', 'did', 'charlie', 'sheen', 'do', 'id', 'like', 'a', 'documentary', 'about', 'doctors', 'in', 'a', 'chicago', 'hospital', 'in', 'the', '1980s', 'find', 'the', 'movies', 'action', 'movies', 'directed', 'by', 'john', 'woo', 'from', 'the', '1990s', 'what', 'is', 'a', 'romantic', 'film', 'where', 'the', 'protagonist', 'doesnt', 'fall', 'in', 'love', 'does', 'the', 'original', 'little', 'mermaid', 'by', 'hans', 'christian', 'anderson', 'come', 'on', 'dvd', 'is', 'there', 'a', 'disney', 'movie', 'where', 'beyonce', 'sang', 'on', 'the', 'soundtrack', 'did', 'shawn', 'levy', 'direct', 'any', 'science', 'fiction', 'movies', 'in', 'the', '2010s', 'any', 'new', 'movie', 'of', 'david', 'dhawan', 'find', 'me', 'all', 'the', 'hannibal', 'lector', 'movies', 'list', 'childrens', 'movies', 'with', 'billy', 'crystal', 'what', 'are', 'the', 'best', 'reviewed', 'movie', 'rock', 'ballads', 'from', 'the', '1980s', 'where', 'were', 'the', 'free', 'willy', 'movies', 'filmed', 'is', 'there', 'a', 'movie', 'with', 'jennifer', 'aniston', 'that', 'is', 'r', 'rated', 'who', 'was', 'the', 'main', 'character', 'in', 'star', 'wars', 'im', 'looking', 'for', 'a', 'musical', 'with', 'the', 'song', 'day', 'by', 'day', 'what', 'movie', 'has', 'the', 'shortest', 'trailer', 'what', 'movie', 'has', 'the', 'song', 'i', 'will', 'always', 'love', 'you', 'i', 'want', 'to', 'see', 'a', 'clint', 'eastwood', 'comedy', 'what', 'was', 'whitney', 'houstons', 'first', 'movie', 'have', 'u', 'had', 'the', 'new', 'trailer', 'of', 'fast', 'and', 'furious', 'in', 'what', 'movie', 'is', 'jack', 'nicholson', 'in', 'an', 'insane', 'asylum', 'list', 'the', 'dramatic', 'movies', 'from', 'the', '1980s', 'starring', 'donald', 'sutherland', 'show', 'me', 'a', 'list', 'of', 'rocky', 'movies', 'what', 'is', 'the', 'aaron', 'sorkin', 'movie', 'that', 'trent', 'reznor', 'did', 'the', 'soundtrack', 'for', 'do', 'you', 'have', 'any', 'films', 'made', 'starring', 'michael', 'jackson', 'in', 'the', '1970s', 'are', 'there', 'political', 'drama', 'movies', 'with', 'alec', 'baldwin', 'in', 'what', 'movie', 'did', 'michael', 'keaton', 'play', 'batman', 'show', 'me', 'movies', 'with', 'ewan', 'macgregor', 'singing', 'show', 'me', 'a', 'list', 'of', 'superman', 'movies', 'what', 'romance', 'movies', 'were', 'popular', 'in', '2002', 'list', 'the', ' ...
# ['are', 'there', 'any', 'good', 'romantic', 'comedies', 'out', 'right', 'now', 'show', 'me', 'a', 'movie', 'about', 'cars', 'that', 'talk', 'list', 'the', 'five', 'star', 'rated', 'movies', 'starring', 'mel', 'gibson', 'what', 'science', 'fiction', 'films', 'have', 'come', 'out', 'recently', 'did', 'the', 'same', 'director', 'make', 'all', 'of', 'the', 'harry', 'potter', 'movies', 'show', 'me', '1980s', 'action', 'movies', 'what', 'is', 'the', 'name', 'of', 'the', 'third', 'movie', 'in', 'the', 'star', 'trek', 'series', 'can', 'you', 'get', 'a', 'soundtrac', 'for', 'the', 'harry', 'potter', 'films', 'find', 'me', 'science', 'fiction', 'movies', 'since', '2005', 'what', 'is', 'the', 'most', 'current', 'movie', 'featuring', 'mat', 'damon', 'show', 'me', 'films', 'where', 'jim', 'carrey', 'is', 'a', 'detective', 'did', 'george', 'clooney', 'make', 'a', 'musical', 'in', 'the', '1980s', 'show', 'me', 'films', 'with', 'both', 'matt', 'damon', 'ad', 'ben', 'affleck', 'what', 'is', 'the', 'borrowers', 'movie', 'have', 'u', 'movie', 'hm', 'about', 'to', 'pg', '18', 'find', 'rated', 'g', 'films', 'with', 'flying', 'cars', 'what', 'was', 'the', 'best', 'rated', 'stanley', 'kubrick', 'film', 'are', 'there', 'any', 'films', 'directed', 'by', 'shawn', 'levy', 'about', 'large', 'families', 'list', 'pg', 'rated', 'movies', 'about', 'cars', 'released', 'in', 'the', '1990s', 'what', 'movie', 'won', 'best', 'picure', 'at', 'the', '2012', 'oscars', 'find', 'me', 'childrens', 'movies', 'with', 'daniel', 'radcliffe', 'from', 'the', '2000s', 'what', 'was', 'the', 'plot', 'behind', '3', 'days', 'of', 'the', 'condor', 'what', 'are', 'considered', 'the', 'must', 'see', 'sci', 'fi', 'movies', 'of', 'the', '1970s', 'who', 'directed', 'the', 'film', 'pulp', 'fiction', 'that', 'starred', 'john', 'travolta', 'which', 'film', 'has', 'the', 'highest', 'viewer', 'rating', 'this', 'year', 'what', 'was', 'the', 'first', 'movie', 'in', 'color', 'may', 'i', 'have', 'the', 'highly', 'acclaimed', 'film', 'from', '1985', 'directed', 'by', 'sylvester', 'stallone', 'list', 'the', 'action', 'films', 'starring', 'hugh', 'jackman', 'what', 'is', 'a', 'bronx', 'tale', 'rated', 'is', 'there', 'a', 'pg', '13', 'movie', 'thats', 'scary', 'what', 'movies', 'made', 'in', '2004', 'were', 'pg', 'find', 'movies', 'with', 'robert', 'diniero', 'in', 'it', 'have', 'pg', '13', 'movies', 'for', 'the', 'kidz', 'list', 'the', 'science', 'fiction', 'movies', 'directed', 'by', 'shawn', 'levy', 'what', 'was', 'the', 'last', 'film', 'elizabeth', 'montgomery', 'starred', 'in', 'did', 'george', 'clooney', 'direct', 'any', 'comedy', 'films', 'what', 'is', 'brad', 'pitts', 'first', 'movie', 'find', 'me', 'the', 'movie', 'that', 'has', 'a', 'aerosmith', 'song', 'are', 'there', 'any', 'drama', 'movies', 'with', 'seth', 'green', 'what', 'is', 'the', 'movie', 'with', 'an', 'aerosmith', 'song', 'what', 'is', 'the', 'highest', 'rated', 'kids', 'new', 'release', 'worst', 'review', 'for', '2011', 'movies', 'show', 'me', 'the', 'milos', 'forman', 'movies', 'from', 'the', '1980s', 'lets', 'find', 'an', 'independent', 'film', 'company', 'which', 'movies', 'were', 'based', 'off', 'of', 'video', 'games', 'besides', 'resident', 'evil', 'did', 'dame', 'judy', 'dench', 'star', 'in', 'a', 'british', 'film', 'about', 'queen', 'elizabeth', 'present', 'list', 'of', 'family', 'movies', 'that', 'chris', 'columbus', 'directed', 'find', 'a', 'movie', 'with', 'dogs', 'as', 'the', 'main', 'character', 'show', 'me', 'movies', 'about', 'horse', 'racing', 'show', 'me', 'morgan', 'freeman', 'movies', 'from', 'the', '90s', 'find', 'me', 'the', 'movies', 'that', 'starred', 'anne', 'hathaway', 'and', 'julie', 'andrews', 'has', 'sandra', 'bullock', 'made', 'any', 'g', 'rated', 'movies', 'list', 'the', 'dirty', 'harry', 'films', 'from', 'the', '1980s', 'show', 'me', 'movies', 'about', 'strippers', 'are', 'there', 'any', 'meg', 'ryan', 'romantic', 'comedy', 'movies', 'that', 'are', 'considered', 'must', 'see', 'what', 'was', 'jame ...

# %%
train_words[0:5]
# Out:
# ['what', 'movies', 'star', 'bruce', 'willis']

# %%
train_labels[0:5]
# Out:
# ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR']

# %%
base_estimator.predict(train_words[0:5])
# Out:
# ['what', 'movies', 'star', 'bruce', 'willis']
# ['O', 'O', 'O', 'B-ACTOR', 'I-ACTOR']

# %%
train_words[3]
# Out:
# 'bruce'

# %%
base_estimator.predict(train_words[2])
# Out:
# star
# ['I-YEAR', 'I-DIRECTOR', 'O', 'B-RATING']

# %%
from sklearn.metrics import classification_report


train_report = classification_report(train_labels, train_preds)

print()
print('TRAINING SET Classification Report')
print()
print(train_report)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# TRAINING SET Classification Report
#
#                    precision    recall  f1-score   support
#
#           B-ACTOR       0.77      0.88      0.82      3220
#       B-CHARACTER       0.77      0.47      0.58       385
#        B-DIRECTOR       0.77      0.63      0.70      1720
#           B-GENRE       0.88      0.95      0.91      4354
#            B-PLOT       0.74      0.68      0.71      1927
#          B-RATING       0.97      0.97      0.97      2007
# B-RATINGS_AVERAGE       0.70      0.64      0.67      1869
#          B-REVIEW       0.78      0.08      0.15       221
#            B-SONG       0.74      0.28      0.40       245
#           B-TITLE       0.77      0.57      0.65      2376
#         B-TRAILER       0.80      0.94      0.87       113
#            B-YEAR       0.92      0.96      0.94      2858
#           I-ACTOR       0.87      0.88      0.88      3474
#       I-CHARACTER       0.72      0.58      0.64       342
#        I-DIRECTOR       0.86      0.81      0.83      1850
#           I-GENRE       0.97      0.53      0.69       786
#            I-PLOT       0.66      0.43      0.52      1687
#          I-RATING       0.99      0.84      0.91       840
# I-RATINGS_AVERAGE       0.68      0.53      0.59      1673
#          I-REVIEW       0.65      0.08      0.15       132
#            I-SONG       0.61      0.28      0.38       446
#           I-TITLE       0.76      0.57      0.65      3495
#         I-TRAILER       0.00      0.00      0.00         7
#            I-YEAR       0.87      0.75      0.81      2456
#                 O       0.92      0.98      0.95     61008
#
#          accuracy                           0.89     99491
#         macro avg       0.77      0.61      0.65     99491
#      weighted avg       0.88      0.89      0.88     99491

# %%
print()
print('TEST SET Classification Report')

f = open(model_dir + 'base_estimator/class_report_test.txt', 'w') 

class_report = classification_report(test_labels, test_preds)
print(class_report, file=f ) 

f.close() 


print(class_report)
# Out:
# TEST SET Classification Report
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                    precision    recall  f1-score   support
#
#           B-ACTOR       0.76      0.84      0.80       812
#       B-CHARACTER       0.69      0.24      0.36        90
#        B-DIRECTOR       0.70      0.50      0.58       456
#           B-GENRE       0.86      0.94      0.90      1117
#            B-PLOT       0.58      0.45      0.51       491
#          B-RATING       0.98      0.97      0.97       500
# B-RATINGS_AVERAGE       0.67      0.61      0.64       451
#          B-REVIEW       0.33      0.02      0.03        56
#            B-SONG       0.36      0.09      0.15        54
#           B-TITLE       0.58      0.35      0.44       562
#         B-TRAILER       0.82      0.90      0.86        30
#            B-YEAR       0.90      0.94      0.92       720
#           I-ACTOR       0.82      0.77      0.80       862
#       I-CHARACTER       0.54      0.25      0.35        75
#        I-DIRECTOR       0.76      0.48      0.59       496
#           I-GENRE       0.91      0.49      0.64       222
#            I-PLOT       0.42      0.21      0.28       496
#          I-RATING       0.98      0.86      0.92       226
# I-RATINGS_AVERAGE       0.63      0.48      0.55       403
#          I-REVIEW       0.00      0.00      0.00        45
#            I-SONG       0.36      0.13      0.20       119
#           I-TITLE       0.58      0.34      0.43       856
#         I-TRAILER       0.00      0.00      0.00         8
#            I-YEAR       0.87      0.74      0.80       610
#                 O       0.87      0.98      0.92     14929
#
#          accuracy                           0.84     24686
#         macro avg       0.64      0.50      0.54     24686
#      weighted avg       0.82      0.84      0.82     24686

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading https://files.pythonhosted.org/packages/9d/2d/233c79d5b4e5ab1dbf111242299153f3caddddbb691219f363ad55ce783d/seqeval-1.2.2.tar.gz (43kB)
#      |████████████████████████████████| 51kB 3.7MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from seqeval) (1.18.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.6/dist-packages (from seqeval) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.3->seqeval) (0.17.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.1)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp36-none-any.whl size=16171 sha256=3a2122c9a31c049a1e1a7a3f3ec2ffebcd57cf841ecf755e7570c167a2f42ee8
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
test_preds = []
for doc in dataset['test_tokens']:
  test_preds.append(base_estimator.predict(doc))

# %%
from seqeval.metrics import classification_report as classification_report_seqeval

f = open(model_dir + 'base_estimator/seq_class_report_test.txt', 'w') 

seq_class_report = classification_report_seqeval(dataset['test_labels'], test_preds)
print(seq_class_report, file=f ) 

f.close() 
print(seq_class_report)
# Out:
#                  precision    recall  f1-score   support
#
#           ACTOR       0.54      0.71      0.61       812
#       CHARACTER       0.31      0.19      0.24        90
#        DIRECTOR       0.35      0.35      0.35       456
#           GENRE       0.78      0.88      0.83      1117
#            PLOT       0.34      0.39      0.37       491
#          RATING       0.93      0.92      0.92       500
# RATINGS_AVERAGE       0.30      0.39      0.34       451
#          REVIEW       0.25      0.02      0.03        56
#            SONG       0.02      0.02      0.02        54
#           TITLE       0.20      0.25      0.23       562
#         TRAILER       0.82      0.90      0.86        30
#            YEAR       0.58      0.74      0.65       720
#
#       micro avg       0.53      0.61      0.57      5339
#       macro avg       0.45      0.48      0.45      5339
#    weighted avg       0.53      0.61      0.57      5339
